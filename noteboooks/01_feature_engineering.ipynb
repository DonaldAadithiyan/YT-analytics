# %%
import pandas as pd 
import os
import numpy as np

# %%
inital_dataset = pd.read_csv("../data/raw/YouTube_Video_Metrics.csv" , engine="python",           # Use Python engine, more tolerant
    quoting=csv.QUOTE_ALL,
    on_bad_lines='skip', )
inital_dataset
# Out:
#           video_id         published_at  \
# 0      __1VyK2eQp8  2025-08-01 14:30:53
# 1      __2_hnYMSsw  2025-08-03 06:44:45
# 2      __2dhBs4XIA  2025-08-05 02:31:10
# 3      __2mImszS_8  2025-08-02 02:00:06
# 4      __3IzcDWTZ8  2025-08-03 03:12:48
# ...            ...                  ...
# 52539  nZLw7sxiqrQ  2025-08-08 04:15:04
# 52540  nzmaoZRNy2E  2025-08-03 01:40:48
# 52541  nZMn3kqmuaY  2025-08-08 03:30:59
# 52542  NZmwihLPxkg  2025-08-03 02:02:29
# 52543  nZn7Xgk_RdU  2025-08-06 23:43:55
#
#                                                    title  \
# 0                               [ASMR] 넷플릭스 메이저 다큐멘터리 찍먹
# 1       Am I Slow???? #track #100m #speed #sports #viral
# 2      GRANNY LIVE 🔴 | Trapped in Granny’s Basement 😱...
# 3      The Importance of Practical Learning in Educat...
# 4                  Observational Documentary Film London
# ...                                                  ...
# 52539  The Council Demanded Submission—Earth Declared...
# 52540  #comedymove #comedyfilms #funny #comedyforever...
# 52541  Trump Slaps 50% Tariffs on India Over Russian ...
# 52542           I LEAKED THE GHOST LMG IN CRAZY 1V1 FFA🤯
# 52543  Classic Events, die heimlichen MVPs des Rennsp...
#
#                                              description  category_id  \
# 0                                asmr 이게 맞나요 진짜 모르겠다 이제.         22.0
# 1                                                    NaN         22.0
# 2      GRANNY LIVE | Trapped in Granny's Basement | F...         20.0
# 3                                                    NaN         27.0
# 4      Shot an observational film capturing a full da...         24.0
# ...                                                  ...          ...
# 52539  The Council Demanded Submission—Earth Declared...         22.0
# 52540                                                NaN         22.0
# 52541  Breaking news! Trump ramps up tariffs to 50% o...         25.0
# 52542  Subscribe for Daily Videos #gaming #youtubesho...         22.0
# 52543  classiccars #Porsche962 #porschemotorsport #Fr...         17.0
#
#        country                                               tags definition  \
# 0      unknown                                            unknown         hd
# 1      unknown                                            unknown         hd
# 2      unknown                                            unknown         hd
# 3           GB                                            unknown         hd
# 4      unknown                                            unknown         hd
# ...        ...                                                ...        ...
# 52539       US  HFY,HFY Story,HFY Short Story,HFY War,Science ...         hd
# 52540  unknown                                            unknown         hd
# 52541       US  #Shorts,#TrumpTariffs,#IndiaTariffs,#RussianOi...         hd
# 52542  unknown                                            unknown         hd
# 52543       DE                                            unknown         hd
#
#                      channel_id    channel_title  ... like_count_initial  \
# 0      UCQHNLiqOCSiHgiLnIqADqCw             동그람이  ...                3.0
# 1      UCy3LY7AfHxsmbbR7-26UDTQ    JamiesVlog2.0  ...                2.0
# 2      UCLUuwHvQpsufGf6MJcrHpKA  INDIAN JK GAMER  ...                0.0
# 3      UCTa4-LmkT71W167cmkj-grA      Craig Miles  ...                0.0
# 4      UCTbweMHZw2Z9uCe-OJQ9CXw    Reshal Dmello  ...                0.0
# ...                         ...              ...  ...                ...
# 52539  UClG9_zRMLYaZPaeZluS2jYA    Solvatica HFY  ...                0.0
# 52540  UCRvaivsZhDg7EIFiljVRmWA     Zata Hada Tv  ...                1.0
# 52541  UCz21JMGwOq90NpSs-hADTgg   Just Some News  ...                2.0
# 52542  UCXCdNr3oN_nX_hBnusaBMDQ       Team Hozzy  ...               22.0
# 52543  UCMvJ8dt3mfCVn89mYzmOIwA          Zwei PS  ...                0.0
#
#        comment_count_initial  c_view_count_initial  \
# 0                        0.0              740384.0
# 1                        0.0               14750.0
# 2                        0.0             3304042.0
# 3                        0.0              105493.0
# 4                        0.0                   0.0
# ...                      ...                   ...
# 52539                    0.0                   8.0
# 52540                    0.0               95006.0
# 52541                    0.0              463470.0
# 52542                    5.0             3410697.0
# 52543                    0.0               23036.0
#
#        c_subscriber_count_initial      logged_at_final  view_count_final  \
# 0                         11400.0  2025-08-01 21:00:04             505.0
# 1                           131.0  2025-08-03 08:00:04               3.0
# 2                         15900.0  2025-08-05 04:00:05              19.0
# 3                           287.0  2025-08-02 03:00:04               2.0
# 4                             0.0  2025-08-03 05:00:04               1.0
# ...                           ...                  ...               ...
# 52539                         0.0  2025-08-08 06:00:24               0.0
# 52540                       749.0  2025-08-03 03:00:23               1.0
# 52541                       256.0  2025-08-08 05:00:24             358.0
# 52542                      9770.0  2025-08-03 04:00:23             781.0
# 52543                        26.0  2025-08-07 01:00:22             291.0
#
#       like_count_final  comment_count_final  c_view_count_final  \
# 0                 29.0                  6.0            741634.0
# 1                  2.0                  0.0             14750.0
# 2                  0.0                  0.0           3304042.0
# 3                  0.0                  0.0            105493.0
# 4                  0.0                  0.0                 0.0
# ...                ...                  ...                 ...
# 52539              0.0                  0.0                 8.0
# 52540              1.0                  0.0             95006.0
# 52541              2.0                  0.0            463470.0
# 52542             35.0                  6.0           3410697.0
# 52543              0.0                  0.0             23036.0
#
#        c_subscriber_count_final
# 0                       11400.0
# 1                         131.0
# 2                       15900.0
# 3                         287.0
# 4                           0.0
# ...                         ...
# 52539                       0.0
# 52540                     749.0
# 52541                     256.0
# 52542                    9780.0
# 52543                      26.0
#
# [52544 rows x 22 columns]

# %%
cleaned_dataset = inital_dataset.drop(columns=["title", "description"])
cleaned_dataset
# Out:
#           video_id         published_at  category_id  country  \
# 0      __1VyK2eQp8  2025-08-01 14:30:53         22.0  unknown
# 1      __2_hnYMSsw  2025-08-03 06:44:45         22.0  unknown
# 2      __2dhBs4XIA  2025-08-05 02:31:10         20.0  unknown
# 3      __2mImszS_8  2025-08-02 02:00:06         27.0       GB
# 4      __3IzcDWTZ8  2025-08-03 03:12:48         24.0  unknown
# ...            ...                  ...          ...      ...
# 52539  nZLw7sxiqrQ  2025-08-08 04:15:04         22.0       US
# 52540  nzmaoZRNy2E  2025-08-03 01:40:48         22.0  unknown
# 52541  nZMn3kqmuaY  2025-08-08 03:30:59         25.0       US
# 52542  NZmwihLPxkg  2025-08-03 02:02:29         22.0  unknown
# 52543  nZn7Xgk_RdU  2025-08-06 23:43:55         17.0       DE
#
#                                                     tags definition  \
# 0                                                unknown         hd
# 1                                                unknown         hd
# 2                                                unknown         hd
# 3                                                unknown         hd
# 4                                                unknown         hd
# ...                                                  ...        ...
# 52539  HFY,HFY Story,HFY Short Story,HFY War,Science ...         hd
# 52540                                            unknown         hd
# 52541  #Shorts,#TrumpTariffs,#IndiaTariffs,#RussianOi...         hd
# 52542                                            unknown         hd
# 52543                                            unknown         hd
#
#                      channel_id    channel_title    logged_at_initial  \
# 0      UCQHNLiqOCSiHgiLnIqADqCw             동그람이  2025-08-01 15:01:29
# 1      UCy3LY7AfHxsmbbR7-26UDTQ    JamiesVlog2.0  2025-08-03 07:01:27
# 2      UCLUuwHvQpsufGf6MJcrHpKA  INDIAN JK GAMER  2025-08-05 03:01:27
# 3      UCTa4-LmkT71W167cmkj-grA      Craig Miles  2025-08-02 02:01:32
# 4      UCTbweMHZw2Z9uCe-OJQ9CXw    Reshal Dmello  2025-08-03 04:01:29
# ...                         ...              ...                  ...
# 52539  UClG9_zRMLYaZPaeZluS2jYA    Solvatica HFY  2025-08-08 05:01:50
# 52540  UCRvaivsZhDg7EIFiljVRmWA     Zata Hada Tv  2025-08-03 02:01:47
# 52541  UCz21JMGwOq90NpSs-hADTgg   Just Some News  2025-08-08 04:01:44
# 52542  UCXCdNr3oN_nX_hBnusaBMDQ       Team Hozzy  2025-08-03 03:01:44
# 52543  UCMvJ8dt3mfCVn89mYzmOIwA          Zwei PS  2025-08-07 00:01:20
#
#        view_count_initial  like_count_initial  comment_count_initial  \
# 0                    53.0                 3.0                    0.0
# 1                     3.0                 2.0                    0.0
# 2                    19.0                 0.0                    0.0
# 3                     2.0                 0.0                    0.0
# 4                     1.0                 0.0                    0.0
# ...                   ...                 ...                    ...
# 52539                 0.0                 0.0                    0.0
# 52540                 1.0                 1.0                    0.0
# 52541               145.0                 2.0                    0.0
# 52542               473.0                22.0                    5.0
# 52543               291.0                 0.0                    0.0
#
#        c_view_count_initial  c_subscriber_count_initial      logged_at_final  \
# 0                  740384.0                     11400.0  2025-08-01 21:00:04
# 1                   14750.0                       131.0  2025-08-03 08:00:04
# 2                 3304042.0                     15900.0  2025-08-05 04:00:05
# 3                  105493.0                       287.0  2025-08-02 03:00:04
# 4                       0.0                         0.0  2025-08-03 05:00:04
# ...                     ...                         ...                  ...
# 52539                   8.0                         0.0  2025-08-08 06:00:24
# 52540               95006.0                       749.0  2025-08-03 03:00:23
# 52541              463470.0                       256.0  2025-08-08 05:00:24
# 52542             3410697.0                      9770.0  2025-08-03 04:00:23
# 52543               23036.0                        26.0  2025-08-07 01:00:22
#
#        view_count_final  like_count_final  comment_count_final  \
# 0                 505.0              29.0                  6.0
# 1                   3.0               2.0                  0.0
# 2                  19.0               0.0                  0.0
# 3                   2.0               0.0                  0.0
# 4                   1.0               0.0                  0.0
# ...                 ...               ...                  ...
# 52539               0.0               0.0                  0.0
# 52540               1.0               1.0                  0.0
# 52541             358.0               2.0                  0.0
# 52542             781.0              35.0                  6.0
# 52543             291.0               0.0                  0.0
#
#        c_view_count_final  c_subscriber_count_final
# 0                741634.0                   11400.0
# 1                 14750.0                     131.0
# 2               3304042.0                   15900.0
# 3                105493.0                     287.0
# 4                     0.0                       0.0
# ...                   ...                       ...
# 52539                 8.0                       0.0
# 52540             95006.0                     749.0
# 52541            463470.0                     256.0
# 52542           3410697.0                    9780.0
# 52543             23036.0                      26.0
#
# [52544 rows x 20 columns]

# %%
# Convert published_at to datetime
inital_dataset["published_at"] = pd.to_datetime(inital_dataset["published_at"])

# Create new columns
inital_dataset["year"] = inital_dataset["published_at"].dt.year
inital_dataset["month"] = inital_dataset["published_at"].dt.month
inital_dataset["day_of_week"] = inital_dataset["published_at"].dt.day_name()
inital_dataset["published_time"] = inital_dataset["published_at"].dt.time  


# Drop the original published_at column
inital_dataset = inital_dataset.drop(columns=["published_at"])

# Optionally, drop other columns as before
cleaned_dataset = inital_dataset.drop(columns=["title", "description"])

# %%
cleaned_dataset = cleaned_dataset.rename(columns={"year": "published_year"})
cleaned_dataset = cleaned_dataset.rename(columns={"month": "published_month"})
cleaned_dataset = cleaned_dataset.rename(columns={"day_of_week": "published_day_of_week"})

# %%
cleaned_dataset
# Out:
#           video_id  category_id  country  \
# 0      __1VyK2eQp8         22.0  unknown
# 1      __2_hnYMSsw         22.0  unknown
# 2      __2dhBs4XIA         20.0  unknown
# 3      __2mImszS_8         27.0       GB
# 4      __3IzcDWTZ8         24.0  unknown
# ...            ...          ...      ...
# 52539  nZLw7sxiqrQ         22.0       US
# 52540  nzmaoZRNy2E         22.0  unknown
# 52541  nZMn3kqmuaY         25.0       US
# 52542  NZmwihLPxkg         22.0  unknown
# 52543  nZn7Xgk_RdU         17.0       DE
#
#                                                     tags definition  \
# 0                                                unknown         hd
# 1                                                unknown         hd
# 2                                                unknown         hd
# 3                                                unknown         hd
# 4                                                unknown         hd
# ...                                                  ...        ...
# 52539  HFY,HFY Story,HFY Short Story,HFY War,Science ...         hd
# 52540                                            unknown         hd
# 52541  #Shorts,#TrumpTariffs,#IndiaTariffs,#RussianOi...         hd
# 52542                                            unknown         hd
# 52543                                            unknown         hd
#
#                      channel_id    channel_title    logged_at_initial  \
# 0      UCQHNLiqOCSiHgiLnIqADqCw             동그람이  2025-08-01 15:01:29
# 1      UCy3LY7AfHxsmbbR7-26UDTQ    JamiesVlog2.0  2025-08-03 07:01:27
# 2      UCLUuwHvQpsufGf6MJcrHpKA  INDIAN JK GAMER  2025-08-05 03:01:27
# 3      UCTa4-LmkT71W167cmkj-grA      Craig Miles  2025-08-02 02:01:32
# 4      UCTbweMHZw2Z9uCe-OJQ9CXw    Reshal Dmello  2025-08-03 04:01:29
# ...                         ...              ...                  ...
# 52539  UClG9_zRMLYaZPaeZluS2jYA    Solvatica HFY  2025-08-08 05:01:50
# 52540  UCRvaivsZhDg7EIFiljVRmWA     Zata Hada Tv  2025-08-03 02:01:47
# 52541  UCz21JMGwOq90NpSs-hADTgg   Just Some News  2025-08-08 04:01:44
# 52542  UCXCdNr3oN_nX_hBnusaBMDQ       Team Hozzy  2025-08-03 03:01:44
# 52543  UCMvJ8dt3mfCVn89mYzmOIwA          Zwei PS  2025-08-07 00:01:20
#
#        view_count_initial  like_count_initial  ...      logged_at_final  \
# 0                    53.0                 3.0  ...  2025-08-01 21:00:04
# 1                     3.0                 2.0  ...  2025-08-03 08:00:04
# 2                    19.0                 0.0  ...  2025-08-05 04:00:05
# 3                     2.0                 0.0  ...  2025-08-02 03:00:04
# 4                     1.0                 0.0  ...  2025-08-03 05:00:04
# ...                   ...                 ...  ...                  ...
# 52539                 0.0                 0.0  ...  2025-08-08 06:00:24
# 52540                 1.0                 1.0  ...  2025-08-03 03:00:23
# 52541               145.0                 2.0  ...  2025-08-08 05:00:24
# 52542               473.0                22.0  ...  2025-08-03 04:00:23
# 52543               291.0                 0.0  ...  2025-08-07 01:00:22
#
#        view_count_final  like_count_final comment_count_final  \
# 0                 505.0              29.0                 6.0
# 1                   3.0               2.0                 0.0
# 2                  19.0               0.0                 0.0
# 3                   2.0               0.0                 0.0
# 4                   1.0               0.0                 0.0
# ...                 ...               ...                 ...
# 52539               0.0               0.0                 0.0
# 52540               1.0               1.0                 0.0
# 52541             358.0               2.0                 0.0
# 52542             781.0              35.0                 6.0
# 52543             291.0               0.0                 0.0
#
#        c_view_count_final  c_subscriber_count_final  published_year  \
# 0                741634.0                   11400.0            2025
# 1                 14750.0                     131.0            2025
# 2               3304042.0                   15900.0            2025
# 3                105493.0                     287.0            2025
# 4                     0.0                       0.0            2025
# ...                   ...                       ...             ...
# 52539                 8.0                       0.0            2025
# 52540             95006.0                     749.0            2025
# 52541            463470.0                     256.0            2025
# 52542           3410697.0                    9780.0            2025
# 52543             23036.0                      26.0            2025
#
#        published_month  published_day_of_week  published_time
# 0                    8                 Friday        14:30:53
# 1                    8                 Sunday        06:44:45
# 2                    8                Tuesday        02:31:10
# 3                    8               Saturday        02:00:06
# 4                    8                 Sunday        03:12:48
# ...                ...                    ...             ...
# 52539                8                 Friday        04:15:04
# 52540                8                 Sunday        01:40:48
# 52541                8                 Friday        03:30:59
# 52542                8                 Sunday        02:02:29
# 52543                8              Wednesday        23:43:55
#
# [52544 rows x 23 columns]

# %%
cleaned_dataset.columns
# Out:
# Index(['video_id', 'category_id', 'country', 'tags', 'definition',
#        'channel_id', 'channel_title', 'logged_at_initial',
#        'view_count_initial', 'like_count_initial', 'comment_count_initial',
#        'c_view_count_initial', 'c_subscriber_count_initial', 'logged_at_final',
#        'view_count_final', 'like_count_final', 'comment_count_final',
#        'c_view_count_final', 'c_subscriber_count_final', 'published_year',
#        'published_month', 'published_day_of_week', 'published_time'],
#       dtype='object')

# %%
cleaned_dataset["view_count_difference"] = cleaned_dataset["view_count_final"] - cleaned_dataset["view_count_initial"]
cleaned_dataset["like_count_difference"] = cleaned_dataset["like_count_final"] - cleaned_dataset["like_count_initial"]

# %%
# Average view count difference per category
avg_view_diff = cleaned_dataset.groupby("category_id")["view_count_difference"].transform("mean")
cleaned_dataset["avg_view_diff_per_category"] = avg_view_diff

# Average likes difference per category
avg_likes_diff = cleaned_dataset.groupby("category_id")["like_count_difference"].transform("mean")
cleaned_dataset["avg_likes_diff_per_category"] = avg_likes_diff

# %%
cleaned_dataset
# Out:
#           video_id  category_id  country  \
# 0      __1VyK2eQp8         22.0  unknown
# 1      __2_hnYMSsw         22.0  unknown
# 2      __2dhBs4XIA         20.0  unknown
# 3      __2mImszS_8         27.0       GB
# 4      __3IzcDWTZ8         24.0  unknown
# ...            ...          ...      ...
# 52539  nZLw7sxiqrQ         22.0       US
# 52540  nzmaoZRNy2E         22.0  unknown
# 52541  nZMn3kqmuaY         25.0       US
# 52542  NZmwihLPxkg         22.0  unknown
# 52543  nZn7Xgk_RdU         17.0       DE
#
#                                                     tags definition  \
# 0                                                unknown         hd
# 1                                                unknown         hd
# 2                                                unknown         hd
# 3                                                unknown         hd
# 4                                                unknown         hd
# ...                                                  ...        ...
# 52539  HFY,HFY Story,HFY Short Story,HFY War,Science ...         hd
# 52540                                            unknown         hd
# 52541  #Shorts,#TrumpTariffs,#IndiaTariffs,#RussianOi...         hd
# 52542                                            unknown         hd
# 52543                                            unknown         hd
#
#                      channel_id    channel_title    logged_at_initial  \
# 0      UCQHNLiqOCSiHgiLnIqADqCw             동그람이  2025-08-01 15:01:29
# 1      UCy3LY7AfHxsmbbR7-26UDTQ    JamiesVlog2.0  2025-08-03 07:01:27
# 2      UCLUuwHvQpsufGf6MJcrHpKA  INDIAN JK GAMER  2025-08-05 03:01:27
# 3      UCTa4-LmkT71W167cmkj-grA      Craig Miles  2025-08-02 02:01:32
# 4      UCTbweMHZw2Z9uCe-OJQ9CXw    Reshal Dmello  2025-08-03 04:01:29
# ...                         ...              ...                  ...
# 52539  UClG9_zRMLYaZPaeZluS2jYA    Solvatica HFY  2025-08-08 05:01:50
# 52540  UCRvaivsZhDg7EIFiljVRmWA     Zata Hada Tv  2025-08-03 02:01:47
# 52541  UCz21JMGwOq90NpSs-hADTgg   Just Some News  2025-08-08 04:01:44
# 52542  UCXCdNr3oN_nX_hBnusaBMDQ       Team Hozzy  2025-08-03 03:01:44
# 52543  UCMvJ8dt3mfCVn89mYzmOIwA          Zwei PS  2025-08-07 00:01:20
#
#        view_count_initial  like_count_initial  ...  c_view_count_final  \
# 0                    53.0                 3.0  ...            741634.0
# 1                     3.0                 2.0  ...             14750.0
# 2                    19.0                 0.0  ...           3304042.0
# 3                     2.0                 0.0  ...            105493.0
# 4                     1.0                 0.0  ...                 0.0
# ...                   ...                 ...  ...                 ...
# 52539                 0.0                 0.0  ...                 8.0
# 52540                 1.0                 1.0  ...             95006.0
# 52541               145.0                 2.0  ...            463470.0
# 52542               473.0                22.0  ...           3410697.0
# 52543               291.0                 0.0  ...             23036.0
#
#        c_subscriber_count_final  published_year published_month  \
# 0                       11400.0            2025               8
# 1                         131.0            2025               8
# 2                       15900.0            2025               8
# 3                         287.0            2025               8
# 4                           0.0            2025               8
# ...                         ...             ...             ...
# 52539                       0.0            2025               8
# 52540                     749.0            2025               8
# 52541                     256.0            2025               8
# 52542                    9780.0            2025               8
# 52543                      26.0            2025               8
#
#        published_day_of_week  published_time  view_count_difference  \
# 0                     Friday        14:30:53                  452.0
# 1                     Sunday        06:44:45                    0.0
# 2                    Tuesday        02:31:10                    0.0
# 3                   Saturday        02:00:06                    0.0
# 4                     Sunday        03:12:48                    0.0
# ...                      ...             ...                    ...
# 52539                 Friday        04:15:04                    0.0
# 52540                 Sunday        01:40:48                    0.0
# 52541                 Friday        03:30:59                  213.0
# 52542                 Sunday        02:02:29                  308.0
# 52543              Wednesday        23:43:55                    0.0
#
#        like_count_difference  avg_view_diff_per_category  \
# 0                       26.0                  669.207479
# 1                        0.0                  669.207479
# 2                        0.0                 7741.158727
# 3                        0.0                  533.657254
# 4                        0.0                 2610.078613
# ...                      ...                         ...
# 52539                    0.0                  669.207479
# 52540                    0.0                  669.207479
# 52541                    0.0                  677.583791
# 52542                   13.0                  669.207479
# 52543                    0.0                 3117.212121
#
#        avg_likes_diff_per_category
# 0                        30.738239
# 1                        30.738239
# 2                        60.068160
# 3                        14.704479
# 4                        80.845175
# ...                            ...
# 52539                    30.738239
# 52540                    30.738239
# 52541                    28.894892
# 52542                    30.738239
# 52543                    49.758249
#
# [52544 rows x 27 columns]

# %%
cleaned_dataset.columns
# Out:
# Index(['video_id', 'category_id', 'country', 'tags', 'definition',
#        'channel_id', 'channel_title', 'logged_at_initial',
#        'view_count_initial', 'like_count_initial', 'comment_count_initial',
#        'c_view_count_initial', 'c_subscriber_count_initial', 'logged_at_final',
#        'view_count_final', 'like_count_final', 'comment_count_final',
#        'c_view_count_final', 'c_subscriber_count_final', 'published_year',
#        'published_month', 'published_day_of_week', 'published_time',
#        'view_count_difference', 'like_count_difference',
#        'avg_view_diff_per_category', 'avg_likes_diff_per_category'],
#       dtype='object')

# %%
cleaned_dataset
# Out:
#           video_id  category_id  country  \
# 0      __1VyK2eQp8         22.0  unknown
# 1      __2_hnYMSsw         22.0  unknown
# 2      __2dhBs4XIA         20.0  unknown
# 3      __2mImszS_8         27.0       GB
# 4      __3IzcDWTZ8         24.0  unknown
# ...            ...          ...      ...
# 52539  nZLw7sxiqrQ         22.0       US
# 52540  nzmaoZRNy2E         22.0  unknown
# 52541  nZMn3kqmuaY         25.0       US
# 52542  NZmwihLPxkg         22.0  unknown
# 52543  nZn7Xgk_RdU         17.0       DE
#
#                                                     tags definition  \
# 0                                                unknown         hd
# 1                                                unknown         hd
# 2                                                unknown         hd
# 3                                                unknown         hd
# 4                                                unknown         hd
# ...                                                  ...        ...
# 52539  HFY,HFY Story,HFY Short Story,HFY War,Science ...         hd
# 52540                                            unknown         hd
# 52541  #Shorts,#TrumpTariffs,#IndiaTariffs,#RussianOi...         hd
# 52542                                            unknown         hd
# 52543                                            unknown         hd
#
#                      channel_id    channel_title    logged_at_initial  \
# 0      UCQHNLiqOCSiHgiLnIqADqCw             동그람이  2025-08-01 15:01:29
# 1      UCy3LY7AfHxsmbbR7-26UDTQ    JamiesVlog2.0  2025-08-03 07:01:27
# 2      UCLUuwHvQpsufGf6MJcrHpKA  INDIAN JK GAMER  2025-08-05 03:01:27
# 3      UCTa4-LmkT71W167cmkj-grA      Craig Miles  2025-08-02 02:01:32
# 4      UCTbweMHZw2Z9uCe-OJQ9CXw    Reshal Dmello  2025-08-03 04:01:29
# ...                         ...              ...                  ...
# 52539  UClG9_zRMLYaZPaeZluS2jYA    Solvatica HFY  2025-08-08 05:01:50
# 52540  UCRvaivsZhDg7EIFiljVRmWA     Zata Hada Tv  2025-08-03 02:01:47
# 52541  UCz21JMGwOq90NpSs-hADTgg   Just Some News  2025-08-08 04:01:44
# 52542  UCXCdNr3oN_nX_hBnusaBMDQ       Team Hozzy  2025-08-03 03:01:44
# 52543  UCMvJ8dt3mfCVn89mYzmOIwA          Zwei PS  2025-08-07 00:01:20
#
#        view_count_initial  like_count_initial  ...  c_view_count_final  \
# 0                    53.0                 3.0  ...            741634.0
# 1                     3.0                 2.0  ...             14750.0
# 2                    19.0                 0.0  ...           3304042.0
# 3                     2.0                 0.0  ...            105493.0
# 4                     1.0                 0.0  ...                 0.0
# ...                   ...                 ...  ...                 ...
# 52539                 0.0                 0.0  ...                 8.0
# 52540                 1.0                 1.0  ...             95006.0
# 52541               145.0                 2.0  ...            463470.0
# 52542               473.0                22.0  ...           3410697.0
# 52543               291.0                 0.0  ...             23036.0
#
#        c_subscriber_count_final  published_year published_month  \
# 0                       11400.0            2025               8
# 1                         131.0            2025               8
# 2                       15900.0            2025               8
# 3                         287.0            2025               8
# 4                           0.0            2025               8
# ...                         ...             ...             ...
# 52539                       0.0            2025               8
# 52540                     749.0            2025               8
# 52541                     256.0            2025               8
# 52542                    9780.0            2025               8
# 52543                      26.0            2025               8
#
#        published_day_of_week  published_time  view_count_difference  \
# 0                     Friday        14:30:53                  452.0
# 1                     Sunday        06:44:45                    0.0
# 2                    Tuesday        02:31:10                    0.0
# 3                   Saturday        02:00:06                    0.0
# 4                     Sunday        03:12:48                    0.0
# ...                      ...             ...                    ...
# 52539                 Friday        04:15:04                    0.0
# 52540                 Sunday        01:40:48                    0.0
# 52541                 Friday        03:30:59                  213.0
# 52542                 Sunday        02:02:29                  308.0
# 52543              Wednesday        23:43:55                    0.0
#
#        like_count_difference  avg_view_diff_per_category  \
# 0                       26.0                  669.207479
# 1                        0.0                  669.207479
# 2                        0.0                 7741.158727
# 3                        0.0                  533.657254
# 4                        0.0                 2610.078613
# ...                      ...                         ...
# 52539                    0.0                  669.207479
# 52540                    0.0                  669.207479
# 52541                    0.0                  677.583791
# 52542                   13.0                  669.207479
# 52543                    0.0                 3117.212121
#
#        avg_likes_diff_per_category
# 0                        30.738239
# 1                        30.738239
# 2                        60.068160
# 3                        14.704479
# 4                        80.845175
# ...                            ...
# 52539                    30.738239
# 52540                    30.738239
# 52541                    28.894892
# 52542                    30.738239
# 52543                    49.758249
#
# [52544 rows x 27 columns]

# %%
cleaned_dataset['channel_authority'] = np.log1p(cleaned_dataset['c_subscriber_count_initial'])

# %%
cleaned_dataset['channel_avg_views'] = cleaned_dataset['c_view_count_initial'] / (cleaned_dataset['c_subscriber_count_initial'] + 1)
cleaned_dataset['channel_growth_potential'] = cleaned_dataset['channel_authority'] * cleaned_dataset['channel_avg_views']
cleaned_dataset['channel_virality_score'] = cleaned_dataset['channel_authority'] * np.log1p(cleaned_dataset['c_subscriber_count_initial'])
cleaned_dataset['log_channel_subs'] = np.log1p(cleaned_dataset['c_subscriber_count_initial'])

# %%
cleaned_dataset['relative_views_to_category'] = cleaned_dataset['c_view_count_initial'] / (cleaned_dataset['avg_view_diff_per_category'] + 1)
cleaned_dataset['relative_likes_to_category'] = cleaned_dataset['channel_authority'] / (cleaned_dataset['avg_likes_diff_per_category'] + 1)

# %%
cleaned_dataset
# Out:
#           video_id  category_id  country  \
# 0      __1VyK2eQp8         22.0  unknown
# 1      __2_hnYMSsw         22.0  unknown
# 2      __2dhBs4XIA         20.0  unknown
# 3      __2mImszS_8         27.0       GB
# 4      __3IzcDWTZ8         24.0  unknown
# ...            ...          ...      ...
# 52539  nZLw7sxiqrQ         22.0       US
# 52540  nzmaoZRNy2E         22.0  unknown
# 52541  nZMn3kqmuaY         25.0       US
# 52542  NZmwihLPxkg         22.0  unknown
# 52543  nZn7Xgk_RdU         17.0       DE
#
#                                                     tags definition  \
# 0                                                unknown         hd
# 1                                                unknown         hd
# 2                                                unknown         hd
# 3                                                unknown         hd
# 4                                                unknown         hd
# ...                                                  ...        ...
# 52539  HFY,HFY Story,HFY Short Story,HFY War,Science ...         hd
# 52540                                            unknown         hd
# 52541  #Shorts,#TrumpTariffs,#IndiaTariffs,#RussianOi...         hd
# 52542                                            unknown         hd
# 52543                                            unknown         hd
#
#                      channel_id    channel_title    logged_at_initial  \
# 0      UCQHNLiqOCSiHgiLnIqADqCw             동그람이  2025-08-01 15:01:29
# 1      UCy3LY7AfHxsmbbR7-26UDTQ    JamiesVlog2.0  2025-08-03 07:01:27
# 2      UCLUuwHvQpsufGf6MJcrHpKA  INDIAN JK GAMER  2025-08-05 03:01:27
# 3      UCTa4-LmkT71W167cmkj-grA      Craig Miles  2025-08-02 02:01:32
# 4      UCTbweMHZw2Z9uCe-OJQ9CXw    Reshal Dmello  2025-08-03 04:01:29
# ...                         ...              ...                  ...
# 52539  UClG9_zRMLYaZPaeZluS2jYA    Solvatica HFY  2025-08-08 05:01:50
# 52540  UCRvaivsZhDg7EIFiljVRmWA     Zata Hada Tv  2025-08-03 02:01:47
# 52541  UCz21JMGwOq90NpSs-hADTgg   Just Some News  2025-08-08 04:01:44
# 52542  UCXCdNr3oN_nX_hBnusaBMDQ       Team Hozzy  2025-08-03 03:01:44
# 52543  UCMvJ8dt3mfCVn89mYzmOIwA          Zwei PS  2025-08-07 00:01:20
#
#        view_count_initial  like_count_initial  ...  like_count_difference  \
# 0                    53.0                 3.0  ...                   26.0
# 1                     3.0                 2.0  ...                    0.0
# 2                    19.0                 0.0  ...                    0.0
# 3                     2.0                 0.0  ...                    0.0
# 4                     1.0                 0.0  ...                    0.0
# ...                   ...                 ...  ...                    ...
# 52539                 0.0                 0.0  ...                    0.0
# 52540                 1.0                 1.0  ...                    0.0
# 52541               145.0                 2.0  ...                    0.0
# 52542               473.0                22.0  ...                   13.0
# 52543               291.0                 0.0  ...                    0.0
#
#        avg_view_diff_per_category  avg_likes_diff_per_category  \
# 0                      669.207479                    30.738239
# 1                      669.207479                    30.738239
# 2                     7741.158727                    60.068160
# 3                      533.657254                    14.704479
# 4                     2610.078613                    80.845175
# ...                           ...                          ...
# 52539                  669.207479                    30.738239
# 52540                  669.207479                    30.738239
# 52541                  677.583791                    28.894892
# 52542                  669.207479                    30.738239
# 52543                 3117.212121                    49.758249
#
#       channel_authority  channel_avg_views  channel_growth_potential  \
# 0              9.341456          64.940268                606.636683
# 1              4.882802         111.742424                545.616124
# 2              9.674137         207.788315               2010.172686
# 3              5.662960         366.295139               2074.314896
# 4              0.000000           0.000000                  0.000000
# ...                 ...                ...                       ...
# 52539          0.000000           8.000000                  0.000000
# 52540          6.620073         126.674667                838.595567
# 52541          5.549076        1803.385214              10007.121763
# 52542          9.187174         349.063248               3206.904833
# 52543          3.295837         853.185185               2811.959187
#
#        channel_virality_score  log_channel_subs  relative_views_to_category  \
# 0                   87.262807          9.341456                 1104.708651
# 1                   23.841755          4.882802                   22.008110
# 2                   93.588932          9.674137                  426.759786
# 3                   32.069121          5.662960                  197.309583
# 4                    0.000000          0.000000                    0.000000
# ...                       ...               ...                         ...
# 52539                0.000000          0.000000                    0.011937
# 52540               43.825369          6.620073                  141.756102
# 52541               30.792245          5.549076                  682.995978
# 52542               84.404168          9.187174                 5089.016622
# 52543               10.862541          3.295837                    7.387567
#
#        relative_likes_to_category
# 0                        0.294328
# 1                        0.153846
# 2                        0.158415
# 3                        0.360595
# 4                        0.000000
# ...                           ...
# 52539                    0.000000
# 52540                    0.208584
# 52541                    0.185620
# 52542                    0.289467
# 52543                    0.064932
#
# [52544 rows x 34 columns]

# %%
cleaned_dataset.columns
# Out:
# Index(['video_id', 'category_id', 'country', 'tags', 'definition',
#        'channel_id', 'channel_title', 'logged_at_initial',
#        'view_count_initial', 'like_count_initial', 'comment_count_initial',
#        'c_view_count_initial', 'c_subscriber_count_initial', 'logged_at_final',
#        'view_count_final', 'like_count_final', 'comment_count_final',
#        'c_view_count_final', 'c_subscriber_count_final', 'published_year',
#        'published_month', 'published_day_of_week', 'published_time',
#        'view_count_difference', 'like_count_difference',
#        'avg_view_diff_per_category', 'avg_likes_diff_per_category',
#        'channel_authority', 'channel_avg_views', 'channel_growth_potential',
#        'channel_virality_score', 'log_channel_subs',
#        'relative_views_to_category', 'relative_likes_to_category'],
#       dtype='object')

# %%
# Save the cleaned and feature-engineered dataset to a specific path
cleaned_dataset.to_csv("../data/feature-engineered/feature_engineered_youtube_data.csv", index=False)

print("Feature-engineered dataset saved to ../data/feature-engineered/feature_engineered_youtube_data.csv")
# Out:
# Feature-engineered dataset saved to ../data/feature-engineered/feature_engineered_youtube_data.csv
