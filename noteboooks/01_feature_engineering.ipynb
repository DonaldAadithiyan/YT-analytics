# %%
import pandas as pd 
import os
import numpy as np

# %%
inital_dataset = pd.read_csv("../data/raw/youtube_vidoe_metrics.csv")
inital_dataset
# Out:
#           video_id         published_at  \
# 0      __1VyK2eQp8  2025-08-01 14:30:53
# 1      __2_hnYMSsw  2025-08-03 06:44:45
# 2      __2mImszS_8  2025-08-02 02:00:06
# 3      __3IzcDWTZ8  2025-08-03 03:12:48
# 4      __GsVCzqwZo  2025-08-02 22:33:57
# ...            ...                  ...
# 25343  zzxEemc5DwI  2025-08-01 09:48:09
# 25344  ZZYJ43I_SBA  2025-08-01 03:38:35
# 25345  zZylRLDi7gU  2025-08-02 14:19:10
# 25346  ZZZJkNM09qc  2025-08-01 21:40:44
# 25347  ZZzqEuET4LM  2025-08-02 11:00:16
#
#                                                    title  \
# 0                               [ASMR] 넷플릭스 메이저 다큐멘터리 찍먹
# 1       Am I Slow???? #track #100m #speed #sports #viral
# 2      The Importance of Practical Learning in Educat...
# 3                  Observational Documentary Film London
# 4      Neza Darakht: Jis Mein Roohain Qaid Hain | Hor...
# ...                                                  ...
# 25343  Amla khane ke fayde 😁😁🤣 #ytshorts #comedy #fun...
# 25344     Tech Education&#39;s Broken System   🎓 #shorts
# 25345  CAPCUT EDIT🔥 | NoobSlayer YT #shorts #FreeFire...
# 25346       How do foreign buyers get $0.30 phone cases?
# 25347  The Greed Lobh | Sumit Choudharry, Roshani Sah...
#
#                                              description  category_id  \
# 0                                asmr 이게 맞나요 진짜 모르겠다 이제.         22.0
# 1                                                    NaN         22.0
# 2                                                    NaN         27.0
# 3      Shot an observational film capturing a full da...         24.0
# 4      Neza Darakht: Jis Mein Roohain Qaid Hain | Hor...         24.0
# ...                                                  ...          ...
# 25343  Amla khane ke fayde #ytshorts #comedy #funny #...         23.0
# 25344  Here's the truth nobody says out loud: Most un...         24.0
# 25345                                                NaN         22.0
# 25346                                                NaN         22.0
# 25347  The Greed Lobh | Sumit Choudharry, Roshani Sah...          1.0
#
#        country                                               tags definition  \
# 0      unknown                                            unknown         hd
# 1      unknown                                            unknown         hd
# 2           GB                                            unknown         hd
# 3      unknown                                            unknown         hd
# 4           IN  horror short film,urdu horror story,scary tree...         hd
# ...        ...                                                ...        ...
# 25343       IN                                            unknown         hd
# 25344       US                                            unknown         hd
# 25345       BD                                            unknown         hd
# 25346  unknown                                            unknown         hd
# 25347       IN  superhit films,Sumit Choudharry,Roshani Sahota...         hd
#
#                      channel_id        channel_title  ... like_count_initial  \
# 0      UCQHNLiqOCSiHgiLnIqADqCw                 동그람이  ...                3.0
# 1      UCy3LY7AfHxsmbbR7-26UDTQ        JamiesVlog2.0  ...                2.0
# 2      UCTa4-LmkT71W167cmkj-grA          Craig Miles  ...                0.0
# 3      UCTbweMHZw2Z9uCe-OJQ9CXw        Reshal Dmello  ...                0.0
# 4      UCuQ0QMMN3OLlh9o1U_8Yllw       Semab Ai Story  ...                0.0
# ...                         ...                  ...  ...                ...
# 25343  UC2o-22oXfxFSwWeSL8sR4HA           MGworld_01  ...                3.0
# 25344  UC26p3I1nr9F8G2WboH1SfTA        Joy of Coding  ...                0.0
# 25345  UCoRqLUOPKq5Xu3qSjJjqKCw       Noob Slayer YT  ...                1.0
# 25346  UCjV27cMOn9LSfjn9L7Jju4Q  HQB8 Sourcing agent  ...                0.0
# 25347  UCuDIZWohRnEyeReO_JG5i8A       Superhit Films  ...                0.0
#
#        comment_count_initial  c_view_count_initial  \
# 0                        0.0              740384.0
# 1                        0.0               14750.0
# 2                        0.0              105493.0
# 3                        0.0                   0.0
# 4                        0.0               18593.0
# ...                      ...                   ...
# 25343                    0.0              810109.0
# 25344                    0.0              127297.0
# 25345                    0.0                3292.0
# 25346                    0.0                   0.0
# 25347                    0.0           250283963.0
#
#        c_subscriber_count_initial      logged_at_final  view_count_final  \
# 0                         11400.0  2025-08-01 21:00:04             505.0
# 1                           131.0  2025-08-03 08:00:04               3.0
# 2                           287.0  2025-08-02 03:00:04               2.0
# 3                             0.0  2025-08-03 05:00:04               1.0
# 4                            52.0  2025-08-03 00:00:05               2.0
# ...                           ...                  ...               ...
# 25343                      1660.0  2025-08-01 11:00:37             196.0
# 25344                      1280.0  2025-08-01 05:00:35             765.0
# 25345                         8.0  2025-08-02 21:00:35              36.0
# 25346                         0.0  2025-08-01 23:00:34               2.0
# 25347                    639000.0  2025-08-02 12:00:35              33.0
#
#       like_count_final  comment_count_final  c_view_count_final  \
# 0                 29.0                  6.0            741634.0
# 1                  2.0                  0.0             14750.0
# 2                  0.0                  0.0            105493.0
# 3                  0.0                  0.0                 0.0
# 4                  0.0                  0.0             18593.0
# ...                ...                  ...                 ...
# 25343              5.0                  0.0            810109.0
# 25344              0.0                  0.0            127297.0
# 25345              3.0                  1.0              3292.0
# 25346              0.0                  0.0                 0.0
# 25347              1.0                  0.0         250283963.0
#
#        c_subscriber_count_final
# 0                       11400.0
# 1                         131.0
# 2                         287.0
# 3                           0.0
# 4                          52.0
# ...                         ...
# 25343                    1660.0
# 25344                    1280.0
# 25345                       9.0
# 25346                       0.0
# 25347                  639000.0
#
# [25348 rows x 22 columns]

# %%
cleaned_dataset = inital_dataset.drop(columns=["title", "description"])
cleaned_dataset
# Out:
#           video_id         published_at  category_id  country  \
# 0      __1VyK2eQp8  2025-08-01 14:30:53         22.0  unknown
# 1      __2_hnYMSsw  2025-08-03 06:44:45         22.0  unknown
# 2      __2mImszS_8  2025-08-02 02:00:06         27.0       GB
# 3      __3IzcDWTZ8  2025-08-03 03:12:48         24.0  unknown
# 4      __GsVCzqwZo  2025-08-02 22:33:57         24.0       IN
# ...            ...                  ...          ...      ...
# 25343  zzxEemc5DwI  2025-08-01 09:48:09         23.0       IN
# 25344  ZZYJ43I_SBA  2025-08-01 03:38:35         24.0       US
# 25345  zZylRLDi7gU  2025-08-02 14:19:10         22.0       BD
# 25346  ZZZJkNM09qc  2025-08-01 21:40:44         22.0  unknown
# 25347  ZZzqEuET4LM  2025-08-02 11:00:16          1.0       IN
#
#                                                     tags definition  \
# 0                                                unknown         hd
# 1                                                unknown         hd
# 2                                                unknown         hd
# 3                                                unknown         hd
# 4      horror short film,urdu horror story,scary tree...         hd
# ...                                                  ...        ...
# 25343                                            unknown         hd
# 25344                                            unknown         hd
# 25345                                            unknown         hd
# 25346                                            unknown         hd
# 25347  superhit films,Sumit Choudharry,Roshani Sahota...         hd
#
#                      channel_id        channel_title    logged_at_initial  \
# 0      UCQHNLiqOCSiHgiLnIqADqCw                 동그람이  2025-08-01 15:01:29
# 1      UCy3LY7AfHxsmbbR7-26UDTQ        JamiesVlog2.0  2025-08-03 07:01:27
# 2      UCTa4-LmkT71W167cmkj-grA          Craig Miles  2025-08-02 02:01:32
# 3      UCTbweMHZw2Z9uCe-OJQ9CXw        Reshal Dmello  2025-08-03 04:01:29
# 4      UCuQ0QMMN3OLlh9o1U_8Yllw       Semab Ai Story  2025-08-02 23:01:26
# ...                         ...                  ...                  ...
# 25343  UC2o-22oXfxFSwWeSL8sR4HA           MGworld_01  2025-08-01 10:02:11
# 25344  UC26p3I1nr9F8G2WboH1SfTA        Joy of Coding  2025-08-01 04:02:02
# 25345  UCoRqLUOPKq5Xu3qSjJjqKCw       Noob Slayer YT  2025-08-02 15:01:55
# 25346  UCjV27cMOn9LSfjn9L7Jju4Q  HQB8 Sourcing agent  2025-08-01 22:01:53
# 25347  UCuDIZWohRnEyeReO_JG5i8A       Superhit Films  2025-08-02 11:02:00
#
#        view_count_initial  like_count_initial  comment_count_initial  \
# 0                    53.0                 3.0                    0.0
# 1                     3.0                 2.0                    0.0
# 2                     2.0                 0.0                    0.0
# 3                     1.0                 0.0                    0.0
# 4                    16.0                 0.0                    0.0
# ...                   ...                 ...                    ...
# 25343               105.0                 3.0                    0.0
# 25344               765.0                 0.0                    0.0
# 25345                25.0                 1.0                    0.0
# 25346                 2.0                 0.0                    0.0
# 25347                 0.0                 0.0                    0.0
#
#        c_view_count_initial  c_subscriber_count_initial      logged_at_final  \
# 0                  740384.0                     11400.0  2025-08-01 21:00:04
# 1                   14750.0                       131.0  2025-08-03 08:00:04
# 2                  105493.0                       287.0  2025-08-02 03:00:04
# 3                       0.0                         0.0  2025-08-03 05:00:04
# 4                   18593.0                        52.0  2025-08-03 00:00:05
# ...                     ...                         ...                  ...
# 25343              810109.0                      1660.0  2025-08-01 11:00:37
# 25344              127297.0                      1280.0  2025-08-01 05:00:35
# 25345                3292.0                         8.0  2025-08-02 21:00:35
# 25346                   0.0                         0.0  2025-08-01 23:00:34
# 25347           250283963.0                    639000.0  2025-08-02 12:00:35
#
#        view_count_final  like_count_final  comment_count_final  \
# 0                 505.0              29.0                  6.0
# 1                   3.0               2.0                  0.0
# 2                   2.0               0.0                  0.0
# 3                   1.0               0.0                  0.0
# 4                   2.0               0.0                  0.0
# ...                 ...               ...                  ...
# 25343             196.0               5.0                  0.0
# 25344             765.0               0.0                  0.0
# 25345              36.0               3.0                  1.0
# 25346               2.0               0.0                  0.0
# 25347              33.0               1.0                  0.0
#
#        c_view_count_final  c_subscriber_count_final
# 0                741634.0                   11400.0
# 1                 14750.0                     131.0
# 2                105493.0                     287.0
# 3                     0.0                       0.0
# 4                 18593.0                      52.0
# ...                   ...                       ...
# 25343            810109.0                    1660.0
# 25344            127297.0                    1280.0
# 25345              3292.0                       9.0
# 25346                 0.0                       0.0
# 25347         250283963.0                  639000.0
#
# [25348 rows x 20 columns]

# %%
# Convert published_at to datetime
inital_dataset["published_at"] = pd.to_datetime(inital_dataset["published_at"])

# Create new columns
inital_dataset["year"] = inital_dataset["published_at"].dt.year
inital_dataset["month"] = inital_dataset["published_at"].dt.month
inital_dataset["day_of_week"] = inital_dataset["published_at"].dt.day_name()
inital_dataset["published_time"] = inital_dataset["published_at"].dt.time  


# Drop the original published_at column
inital_dataset = inital_dataset.drop(columns=["published_at"])

# Optionally, drop other columns as before
cleaned_dataset = inital_dataset.drop(columns=["title", "description"])

# %%
cleaned_dataset = cleaned_dataset.rename(columns={"year": "published_year"})
cleaned_dataset = cleaned_dataset.rename(columns={"month": "published_month"})
cleaned_dataset = cleaned_dataset.rename(columns={"day_of_week": "published_day_of_week"})

# %%
cleaned_dataset
# Out:
#           video_id  category_id  country  \
# 0      __1VyK2eQp8         22.0  unknown
# 1      __2_hnYMSsw         22.0  unknown
# 2      __2mImszS_8         27.0       GB
# 3      __3IzcDWTZ8         24.0  unknown
# 4      __GsVCzqwZo         24.0       IN
# ...            ...          ...      ...
# 25343  zzxEemc5DwI         23.0       IN
# 25344  ZZYJ43I_SBA         24.0       US
# 25345  zZylRLDi7gU         22.0       BD
# 25346  ZZZJkNM09qc         22.0  unknown
# 25347  ZZzqEuET4LM          1.0       IN
#
#                                                     tags definition  \
# 0                                                unknown         hd
# 1                                                unknown         hd
# 2                                                unknown         hd
# 3                                                unknown         hd
# 4      horror short film,urdu horror story,scary tree...         hd
# ...                                                  ...        ...
# 25343                                            unknown         hd
# 25344                                            unknown         hd
# 25345                                            unknown         hd
# 25346                                            unknown         hd
# 25347  superhit films,Sumit Choudharry,Roshani Sahota...         hd
#
#                      channel_id        channel_title    logged_at_initial  \
# 0      UCQHNLiqOCSiHgiLnIqADqCw                 동그람이  2025-08-01 15:01:29
# 1      UCy3LY7AfHxsmbbR7-26UDTQ        JamiesVlog2.0  2025-08-03 07:01:27
# 2      UCTa4-LmkT71W167cmkj-grA          Craig Miles  2025-08-02 02:01:32
# 3      UCTbweMHZw2Z9uCe-OJQ9CXw        Reshal Dmello  2025-08-03 04:01:29
# 4      UCuQ0QMMN3OLlh9o1U_8Yllw       Semab Ai Story  2025-08-02 23:01:26
# ...                         ...                  ...                  ...
# 25343  UC2o-22oXfxFSwWeSL8sR4HA           MGworld_01  2025-08-01 10:02:11
# 25344  UC26p3I1nr9F8G2WboH1SfTA        Joy of Coding  2025-08-01 04:02:02
# 25345  UCoRqLUOPKq5Xu3qSjJjqKCw       Noob Slayer YT  2025-08-02 15:01:55
# 25346  UCjV27cMOn9LSfjn9L7Jju4Q  HQB8 Sourcing agent  2025-08-01 22:01:53
# 25347  UCuDIZWohRnEyeReO_JG5i8A       Superhit Films  2025-08-02 11:02:00
#
#        view_count_initial  like_count_initial  ...      logged_at_final  \
# 0                    53.0                 3.0  ...  2025-08-01 21:00:04
# 1                     3.0                 2.0  ...  2025-08-03 08:00:04
# 2                     2.0                 0.0  ...  2025-08-02 03:00:04
# 3                     1.0                 0.0  ...  2025-08-03 05:00:04
# 4                    16.0                 0.0  ...  2025-08-03 00:00:05
# ...                   ...                 ...  ...                  ...
# 25343               105.0                 3.0  ...  2025-08-01 11:00:37
# 25344               765.0                 0.0  ...  2025-08-01 05:00:35
# 25345                25.0                 1.0  ...  2025-08-02 21:00:35
# 25346                 2.0                 0.0  ...  2025-08-01 23:00:34
# 25347                 0.0                 0.0  ...  2025-08-02 12:00:35
#
#        view_count_final  like_count_final comment_count_final  \
# 0                 505.0              29.0                 6.0
# 1                   3.0               2.0                 0.0
# 2                   2.0               0.0                 0.0
# 3                   1.0               0.0                 0.0
# 4                   2.0               0.0                 0.0
# ...                 ...               ...                 ...
# 25343             196.0               5.0                 0.0
# 25344             765.0               0.0                 0.0
# 25345              36.0               3.0                 1.0
# 25346               2.0               0.0                 0.0
# 25347              33.0               1.0                 0.0
#
#        c_view_count_final  c_subscriber_count_final  published_year  \
# 0                741634.0                   11400.0            2025
# 1                 14750.0                     131.0            2025
# 2                105493.0                     287.0            2025
# 3                     0.0                       0.0            2025
# 4                 18593.0                      52.0            2025
# ...                   ...                       ...             ...
# 25343            810109.0                    1660.0            2025
# 25344            127297.0                    1280.0            2025
# 25345              3292.0                       9.0            2025
# 25346                 0.0                       0.0            2025
# 25347         250283963.0                  639000.0            2025
#
#        published_month  published_day_of_week  published_time
# 0                    8                 Friday        14:30:53
# 1                    8                 Sunday        06:44:45
# 2                    8               Saturday        02:00:06
# 3                    8                 Sunday        03:12:48
# 4                    8               Saturday        22:33:57
# ...                ...                    ...             ...
# 25343                8                 Friday        09:48:09
# 25344                8                 Friday        03:38:35
# 25345                8               Saturday        14:19:10
# 25346                8                 Friday        21:40:44
# 25347                8               Saturday        11:00:16
#
# [25348 rows x 23 columns]

# %%
cleaned_dataset.columns
# Out:
# Index(['video_id', 'category_id', 'country', 'tags', 'definition',
#        'channel_id', 'channel_title', 'logged_at_initial',
#        'view_count_initial', 'like_count_initial', 'comment_count_initial',
#        'c_view_count_initial', 'c_subscriber_count_initial', 'logged_at_final',
#        'view_count_final', 'like_count_final', 'comment_count_final',
#        'c_view_count_final', 'c_subscriber_count_final', 'published_year',
#        'published_month', 'published_day_of_week', 'published_time'],
#       dtype='object')

# %%
cleaned_dataset["view_count_difference"] = cleaned_dataset["view_count_final"] - cleaned_dataset["view_count_initial"]
cleaned_dataset["like_count_difference"] = cleaned_dataset["like_count_final"] - cleaned_dataset["like_count_initial"]

# %%
# Average view count difference per category
avg_view_diff = cleaned_dataset.groupby("category_id")["view_count_difference"].transform("mean")
cleaned_dataset["avg_view_diff_per_category"] = avg_view_diff

# Average likes difference per category
avg_likes_diff = cleaned_dataset.groupby("category_id")["like_count_difference"].transform("mean")
cleaned_dataset["avg_likes_diff_per_category"] = avg_likes_diff

# %%
cleaned_dataset
# Out:
#           video_id  category_id  country  \
# 0      __1VyK2eQp8         22.0  unknown
# 1      __2_hnYMSsw         22.0  unknown
# 2      __2mImszS_8         27.0       GB
# 3      __3IzcDWTZ8         24.0  unknown
# 4      __GsVCzqwZo         24.0       IN
# ...            ...          ...      ...
# 25343  zzxEemc5DwI         23.0       IN
# 25344  ZZYJ43I_SBA         24.0       US
# 25345  zZylRLDi7gU         22.0       BD
# 25346  ZZZJkNM09qc         22.0  unknown
# 25347  ZZzqEuET4LM          1.0       IN
#
#                                                     tags definition  \
# 0                                                unknown         hd
# 1                                                unknown         hd
# 2                                                unknown         hd
# 3                                                unknown         hd
# 4      horror short film,urdu horror story,scary tree...         hd
# ...                                                  ...        ...
# 25343                                            unknown         hd
# 25344                                            unknown         hd
# 25345                                            unknown         hd
# 25346                                            unknown         hd
# 25347  superhit films,Sumit Choudharry,Roshani Sahota...         hd
#
#                      channel_id        channel_title    logged_at_initial  \
# 0      UCQHNLiqOCSiHgiLnIqADqCw                 동그람이  2025-08-01 15:01:29
# 1      UCy3LY7AfHxsmbbR7-26UDTQ        JamiesVlog2.0  2025-08-03 07:01:27
# 2      UCTa4-LmkT71W167cmkj-grA          Craig Miles  2025-08-02 02:01:32
# 3      UCTbweMHZw2Z9uCe-OJQ9CXw        Reshal Dmello  2025-08-03 04:01:29
# 4      UCuQ0QMMN3OLlh9o1U_8Yllw       Semab Ai Story  2025-08-02 23:01:26
# ...                         ...                  ...                  ...
# 25343  UC2o-22oXfxFSwWeSL8sR4HA           MGworld_01  2025-08-01 10:02:11
# 25344  UC26p3I1nr9F8G2WboH1SfTA        Joy of Coding  2025-08-01 04:02:02
# 25345  UCoRqLUOPKq5Xu3qSjJjqKCw       Noob Slayer YT  2025-08-02 15:01:55
# 25346  UCjV27cMOn9LSfjn9L7Jju4Q  HQB8 Sourcing agent  2025-08-01 22:01:53
# 25347  UCuDIZWohRnEyeReO_JG5i8A       Superhit Films  2025-08-02 11:02:00
#
#        view_count_initial  like_count_initial  ...  c_view_count_final  \
# 0                    53.0                 3.0  ...            741634.0
# 1                     3.0                 2.0  ...             14750.0
# 2                     2.0                 0.0  ...            105493.0
# 3                     1.0                 0.0  ...                 0.0
# 4                    16.0                 0.0  ...             18593.0
# ...                   ...                 ...  ...                 ...
# 25343               105.0                 3.0  ...            810109.0
# 25344               765.0                 0.0  ...            127297.0
# 25345                25.0                 1.0  ...              3292.0
# 25346                 2.0                 0.0  ...                 0.0
# 25347                 0.0                 0.0  ...         250283963.0
#
#        c_subscriber_count_final  published_year published_month  \
# 0                       11400.0            2025               8
# 1                         131.0            2025               8
# 2                         287.0            2025               8
# 3                           0.0            2025               8
# 4                          52.0            2025               8
# ...                         ...             ...             ...
# 25343                    1660.0            2025               8
# 25344                    1280.0            2025               8
# 25345                       9.0            2025               8
# 25346                       0.0            2025               8
# 25347                  639000.0            2025               8
#
#        published_day_of_week  published_time  view_count_difference  \
# 0                     Friday        14:30:53                  452.0
# 1                     Sunday        06:44:45                    0.0
# 2                   Saturday        02:00:06                    0.0
# 3                     Sunday        03:12:48                    0.0
# 4                   Saturday        22:33:57                  -14.0
# ...                      ...             ...                    ...
# 25343                 Friday        09:48:09                   91.0
# 25344                 Friday        03:38:35                    0.0
# 25345               Saturday        14:19:10                   11.0
# 25346                 Friday        21:40:44                    0.0
# 25347               Saturday        11:00:16                   33.0
#
#        like_count_difference  avg_view_diff_per_category  \
# 0                       26.0                  760.531441
# 1                        0.0                  760.531441
# 2                        0.0                  359.859938
# 3                        0.0                 2744.971185
# 4                        0.0                 2744.971185
# ...                      ...                         ...
# 25343                    2.0                 1538.560000
# 25344                    0.0                 2744.971185
# 25345                    2.0                  760.531441
# 25346                    0.0                  760.531441
# 25347                    1.0                  786.259055
#
#        avg_likes_diff_per_category
# 0                        34.178829
# 1                        34.178829
# 2                        15.439753
# 3                        64.371586
# 4                        64.371586
# ...                            ...
# 25343                   106.478667
# 25344                    64.371586
# 25345                    34.178829
# 25346                    34.178829
# 25347                    46.288189
#
# [25348 rows x 27 columns]

# %%
cleaned_dataset.columns
# Out:
# Index(['video_id', 'category_id', 'country', 'tags', 'definition',
#        'channel_id', 'channel_title', 'logged_at_initial',
#        'view_count_initial', 'like_count_initial', 'comment_count_initial',
#        'c_view_count_initial', 'c_subscriber_count_initial', 'logged_at_final',
#        'view_count_final', 'like_count_final', 'comment_count_final',
#        'c_view_count_final', 'c_subscriber_count_final', 'published_year',
#        'published_month', 'published_day_of_week', 'published_time',
#        'view_count_difference', 'like_count_difference',
#        'avg_view_diff_per_category', 'avg_likes_diff_per_category'],
#       dtype='object')

# %%
cleaned_dataset
# Out:
#           video_id  category_id  country  \
# 0      __1VyK2eQp8         22.0  unknown
# 1      __2_hnYMSsw         22.0  unknown
# 2      __2mImszS_8         27.0       GB
# 3      __3IzcDWTZ8         24.0  unknown
# 4      __GsVCzqwZo         24.0       IN
# ...            ...          ...      ...
# 25343  zzxEemc5DwI         23.0       IN
# 25344  ZZYJ43I_SBA         24.0       US
# 25345  zZylRLDi7gU         22.0       BD
# 25346  ZZZJkNM09qc         22.0  unknown
# 25347  ZZzqEuET4LM          1.0       IN
#
#                                                     tags definition  \
# 0                                                unknown         hd
# 1                                                unknown         hd
# 2                                                unknown         hd
# 3                                                unknown         hd
# 4      horror short film,urdu horror story,scary tree...         hd
# ...                                                  ...        ...
# 25343                                            unknown         hd
# 25344                                            unknown         hd
# 25345                                            unknown         hd
# 25346                                            unknown         hd
# 25347  superhit films,Sumit Choudharry,Roshani Sahota...         hd
#
#                      channel_id        channel_title    logged_at_initial  \
# 0      UCQHNLiqOCSiHgiLnIqADqCw                 동그람이  2025-08-01 15:01:29
# 1      UCy3LY7AfHxsmbbR7-26UDTQ        JamiesVlog2.0  2025-08-03 07:01:27
# 2      UCTa4-LmkT71W167cmkj-grA          Craig Miles  2025-08-02 02:01:32
# 3      UCTbweMHZw2Z9uCe-OJQ9CXw        Reshal Dmello  2025-08-03 04:01:29
# 4      UCuQ0QMMN3OLlh9o1U_8Yllw       Semab Ai Story  2025-08-02 23:01:26
# ...                         ...                  ...                  ...
# 25343  UC2o-22oXfxFSwWeSL8sR4HA           MGworld_01  2025-08-01 10:02:11
# 25344  UC26p3I1nr9F8G2WboH1SfTA        Joy of Coding  2025-08-01 04:02:02
# 25345  UCoRqLUOPKq5Xu3qSjJjqKCw       Noob Slayer YT  2025-08-02 15:01:55
# 25346  UCjV27cMOn9LSfjn9L7Jju4Q  HQB8 Sourcing agent  2025-08-01 22:01:53
# 25347  UCuDIZWohRnEyeReO_JG5i8A       Superhit Films  2025-08-02 11:02:00
#
#        view_count_initial  like_count_initial  ...  c_view_count_final  \
# 0                    53.0                 3.0  ...            741634.0
# 1                     3.0                 2.0  ...             14750.0
# 2                     2.0                 0.0  ...            105493.0
# 3                     1.0                 0.0  ...                 0.0
# 4                    16.0                 0.0  ...             18593.0
# ...                   ...                 ...  ...                 ...
# 25343               105.0                 3.0  ...            810109.0
# 25344               765.0                 0.0  ...            127297.0
# 25345                25.0                 1.0  ...              3292.0
# 25346                 2.0                 0.0  ...                 0.0
# 25347                 0.0                 0.0  ...         250283963.0
#
#        c_subscriber_count_final  published_year published_month  \
# 0                       11400.0            2025               8
# 1                         131.0            2025               8
# 2                         287.0            2025               8
# 3                           0.0            2025               8
# 4                          52.0            2025               8
# ...                         ...             ...             ...
# 25343                    1660.0            2025               8
# 25344                    1280.0            2025               8
# 25345                       9.0            2025               8
# 25346                       0.0            2025               8
# 25347                  639000.0            2025               8
#
#        published_day_of_week  published_time  view_count_difference  \
# 0                     Friday        14:30:53                  452.0
# 1                     Sunday        06:44:45                    0.0
# 2                   Saturday        02:00:06                    0.0
# 3                     Sunday        03:12:48                    0.0
# 4                   Saturday        22:33:57                  -14.0
# ...                      ...             ...                    ...
# 25343                 Friday        09:48:09                   91.0
# 25344                 Friday        03:38:35                    0.0
# 25345               Saturday        14:19:10                   11.0
# 25346                 Friday        21:40:44                    0.0
# 25347               Saturday        11:00:16                   33.0
#
#        like_count_difference  avg_view_diff_per_category  \
# 0                       26.0                  760.531441
# 1                        0.0                  760.531441
# 2                        0.0                  359.859938
# 3                        0.0                 2744.971185
# 4                        0.0                 2744.971185
# ...                      ...                         ...
# 25343                    2.0                 1538.560000
# 25344                    0.0                 2744.971185
# 25345                    2.0                  760.531441
# 25346                    0.0                  760.531441
# 25347                    1.0                  786.259055
#
#        avg_likes_diff_per_category
# 0                        34.178829
# 1                        34.178829
# 2                        15.439753
# 3                        64.371586
# 4                        64.371586
# ...                            ...
# 25343                   106.478667
# 25344                    64.371586
# 25345                    34.178829
# 25346                    34.178829
# 25347                    46.288189
#
# [25348 rows x 27 columns]

# %%
cleaned_dataset['channel_authority'] = np.log1p(cleaned_dataset['c_subscriber_count_initial'])

# %%
cleaned_dataset['channel_avg_views'] = cleaned_dataset['c_view_count_initial'] / (cleaned_dataset['c_subscriber_count_initial'] + 1)
cleaned_dataset['channel_growth_potential'] = cleaned_dataset['channel_authority'] * cleaned_dataset['channel_avg_views']
cleaned_dataset['channel_virality_score'] = cleaned_dataset['channel_authority'] * np.log1p(cleaned_dataset['c_subscriber_count_initial'])
cleaned_dataset['log_channel_subs'] = np.log1p(cleaned_dataset['c_subscriber_count_initial'])

# %%
cleaned_dataset['relative_views_to_category'] = cleaned_dataset['c_view_count_initial'] / (cleaned_dataset['avg_view_diff_per_category'] + 1)
cleaned_dataset['relative_likes_to_category'] = cleaned_dataset['channel_authority'] / (cleaned_dataset['avg_likes_diff_per_category'] + 1)

# %%
cleaned_dataset
# Out:
#           video_id  category_id  country  \
# 0      __1VyK2eQp8         22.0  unknown
# 1      __2_hnYMSsw         22.0  unknown
# 2      __2mImszS_8         27.0       GB
# 3      __3IzcDWTZ8         24.0  unknown
# 4      __GsVCzqwZo         24.0       IN
# ...            ...          ...      ...
# 25343  zzxEemc5DwI         23.0       IN
# 25344  ZZYJ43I_SBA         24.0       US
# 25345  zZylRLDi7gU         22.0       BD
# 25346  ZZZJkNM09qc         22.0  unknown
# 25347  ZZzqEuET4LM          1.0       IN
#
#                                                     tags definition  \
# 0                                                unknown         hd
# 1                                                unknown         hd
# 2                                                unknown         hd
# 3                                                unknown         hd
# 4      horror short film,urdu horror story,scary tree...         hd
# ...                                                  ...        ...
# 25343                                            unknown         hd
# 25344                                            unknown         hd
# 25345                                            unknown         hd
# 25346                                            unknown         hd
# 25347  superhit films,Sumit Choudharry,Roshani Sahota...         hd
#
#                      channel_id        channel_title    logged_at_initial  \
# 0      UCQHNLiqOCSiHgiLnIqADqCw                 동그람이  2025-08-01 15:01:29
# 1      UCy3LY7AfHxsmbbR7-26UDTQ        JamiesVlog2.0  2025-08-03 07:01:27
# 2      UCTa4-LmkT71W167cmkj-grA          Craig Miles  2025-08-02 02:01:32
# 3      UCTbweMHZw2Z9uCe-OJQ9CXw        Reshal Dmello  2025-08-03 04:01:29
# 4      UCuQ0QMMN3OLlh9o1U_8Yllw       Semab Ai Story  2025-08-02 23:01:26
# ...                         ...                  ...                  ...
# 25343  UC2o-22oXfxFSwWeSL8sR4HA           MGworld_01  2025-08-01 10:02:11
# 25344  UC26p3I1nr9F8G2WboH1SfTA        Joy of Coding  2025-08-01 04:02:02
# 25345  UCoRqLUOPKq5Xu3qSjJjqKCw       Noob Slayer YT  2025-08-02 15:01:55
# 25346  UCjV27cMOn9LSfjn9L7Jju4Q  HQB8 Sourcing agent  2025-08-01 22:01:53
# 25347  UCuDIZWohRnEyeReO_JG5i8A       Superhit Films  2025-08-02 11:02:00
#
#        view_count_initial  like_count_initial  ...  like_count_difference  \
# 0                    53.0                 3.0  ...                   26.0
# 1                     3.0                 2.0  ...                    0.0
# 2                     2.0                 0.0  ...                    0.0
# 3                     1.0                 0.0  ...                    0.0
# 4                    16.0                 0.0  ...                    0.0
# ...                   ...                 ...  ...                    ...
# 25343               105.0                 3.0  ...                    2.0
# 25344               765.0                 0.0  ...                    0.0
# 25345                25.0                 1.0  ...                    2.0
# 25346                 2.0                 0.0  ...                    0.0
# 25347                 0.0                 0.0  ...                    1.0
#
#        avg_view_diff_per_category  avg_likes_diff_per_category  \
# 0                      760.531441                    34.178829
# 1                      760.531441                    34.178829
# 2                      359.859938                    15.439753
# 3                     2744.971185                    64.371586
# 4                     2744.971185                    64.371586
# ...                           ...                          ...
# 25343                 1538.560000                   106.478667
# 25344                 2744.971185                    64.371586
# 25345                  760.531441                    34.178829
# 25346                  760.531441                    34.178829
# 25347                  786.259055                    46.288189
#
#       channel_authority  channel_avg_views  channel_growth_potential  \
# 0              9.341456          64.940268                606.636683
# 1              4.882802         111.742424                545.616124
# 2              5.662960         366.295139               2074.314896
# 3              0.000000           0.000000                  0.000000
# 4              3.970292         350.811321               1392.823350
# ...                 ...                ...                       ...
# 25343          7.415175         487.723660               3616.556347
# 25344          7.155396          99.373146                711.054241
# 25345          2.197225         365.777778                803.695923
# 25346          0.000000           0.000000                  0.000000
# 25347         13.367661         391.680080               5235.846651
#
#        channel_virality_score  log_channel_subs  relative_views_to_category  \
# 0                   87.262807          9.341456                  972.230376
# 1                   23.841755          4.882802                   19.368865
# 2                   32.069121          5.662960                  292.337799
# 3                    0.000000          0.000000                    0.000000
# 4                   15.763218          3.970292                    6.771011
# ...                       ...               ...                         ...
# 25343               54.984822          7.415175                  526.195147
# 25344               51.199696          7.155396                   46.357733
# 25345                4.827796          2.197225                    4.322868
# 25346                0.000000          0.000000                    0.000000
# 25347              178.694369         13.367661               317918.176200
#
#        relative_likes_to_category
# 0                        0.265542
# 1                        0.138799
# 2                        0.344467
# 3                        0.000000
# 4                        0.060734
# ...                           ...
# 25343                    0.068992
# 25344                    0.109457
# 25345                    0.062459
# 25346                    0.000000
# 25347                    0.282685
#
# [25348 rows x 34 columns]

# %%
cleaned_dataset.columns
# Out:
# Index(['video_id', 'category_id', 'country', 'tags', 'definition',
#        'channel_id', 'channel_title', 'logged_at_initial',
#        'view_count_initial', 'like_count_initial', 'comment_count_initial',
#        'c_view_count_initial', 'c_subscriber_count_initial', 'logged_at_final',
#        'view_count_final', 'like_count_final', 'comment_count_final',
#        'c_view_count_final', 'c_subscriber_count_final', 'published_year',
#        'published_month', 'published_day_of_week', 'published_time',
#        'view_count_difference', 'like_count_difference',
#        'avg_view_diff_per_category', 'avg_likes_diff_per_category',
#        'channel_authority', 'channel_avg_views', 'channel_growth_potential',
#        'channel_virality_score', 'log_channel_subs',
#        'relative_views_to_category', 'relative_likes_to_category'],
#       dtype='object')

# %%
# Save the cleaned and feature-engineered dataset to a specific path
cleaned_dataset.to_csv("../data/feature-engineered/feature_engineered_youtube_data.csv", index=False)

print("Feature-engineered dataset saved to ../data/feature-engineered/feature_engineered_youtube_data.csv")
# Out:
# Feature-engineered dataset saved to ../data/feature-engineered/feature_engineered_youtube_data.csv
